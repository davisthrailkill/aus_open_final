# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# This will be an exploration of the 2019 Australian Open Final

# %%
events = pd.read_csv('data/events.csv')
points = pd.read_csv('data/points.csv')
rallies = pd.read_csv('data/rallies.csv')
serves = pd.read_csv('data/serves.csv')

# %%
events.head()
# Out:
#    Unnamed: 0  rallyid  frameid  strokeid    hitter  receiver  isserve  \
# 0           0        1    70877         1  Djokovic     Nadal     True
# 1           1        1    70900         2     Nadal  Djokovic    False
# 2           2        1    70950         3  Djokovic     Nadal    False
# 3           3        2    71488         1  Djokovic     Nadal     True
# 4           4        3    71796         1  Djokovic     Nadal     True
#
#     serve     type    stroke  hitter_x  hitter_y  receiver_x  receiver_y  \
# 0   first    serve  forehand      6.50     -0.24        1.03       27.44
# 1   first    slice  backhand      0.05     25.59        6.17        1.11
# 2   first  topspin  forehand      1.42      2.33        4.75       26.45
# 3   first    serve  forehand      4.48     -0.01        7.90       26.83
# 4  second    serve  forehand      4.48     -0.37        7.88       26.47
#
#     time
# 0   0.00
# 1   0.92
# 2   2.92
# 3  24.44
# 4  36.76

# %%
points.head()
# Out:
#    Unnamed: 0  rallyid    server  returner    winner  reason   serve  strokes  \
# 0           0        1  Djokovic     Nadal  Djokovic  winner   first        3
# 1           2        3  Djokovic     Nadal  Djokovic     out  second        4
# 2           4        5  Djokovic     Nadal  Djokovic     ace  second        2
# 3           5        6  Djokovic     Nadal  Djokovic     net   first       10
# 4           7        8     Nadal  Djokovic  Djokovic     out  second        7
#
#    totaltime     x      y      score
# 0       0.92  1.92  21.96  0:0, 15:0
# 1       4.16  3.33  -0.39  0:0, 30:0
# 2       0.40  1.62  17.18  0:0, 40:0
# 3      10.40  6.41  12.78   1:0, 0:0
# 4       7.20  0.50  18.67  1:0, 15:0

# %%
rallies.head()
# Out:
#    Unnamed: 0  rallyid    server returner         winner        reason  \
# 0           0        1  Djokovic    Nadal       Djokovic        winner
# 1           1        2  Djokovic    Nadal  __undefined__  second_serve
# 2           2        3  Djokovic    Nadal       Djokovic           out
# 3           3        4  Djokovic    Nadal  __undefined__  second_serve
# 4           4        5  Djokovic    Nadal       Djokovic           ace
#
#     serve  strokes  totaltime     x      y
# 0   first        3       0.92  1.92  21.96
# 1   first        1       0.00  7.42  12.10
# 2  second        4       4.16  3.33  -0.39
# 3   first        1       0.00  4.64  17.69
# 4  second        2       0.40  1.62  17.18

# %%
serves.head()
# Out:
#    Unnamed: 0  rallyid    server     x      y
# 0           0        1  Djokovic  1.86  16.80
# 1           1        3  Djokovic  7.05  16.97
# 2           2        6  Djokovic  8.04  17.80
# 3           3        8     Nadal  4.44  16.24
# 4           4        9     Nadal  5.71  16.40
